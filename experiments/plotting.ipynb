# %%
import sys
sys.path.append('../')
from util.plotting import *

# %% [markdown]
# ### Plotting Notebook
# The following is a plotting notebook made to plot multiple streams of architecture data at once for comparison purposes.
#
# The dataloading primitive is as follows:
#
# 1. Provide a txt file containing plain formatted lists (`See vgg16_v1_performance.txt for example`)
#
# 2. Parse data using `read_data_from_file` for each file storing retrieved string into a list
#
# 3. Pass entire list of datasets to `plot_all_metrics` for simultaneous plotting

# %% [markdown]
# #### VGG_16

# %%
file_path_1= '../performance_data/vgg_16/model_1/model_1.txt'  
data_1 = read_data_from_file(file_path_1)
file_path_2= '../performance_data/vgg_16/model_2/model_2.txt'  
data_2 = read_data_from_file(file_path_2)
file_path_3= '../performance_data/vgg_16/model_3/model_3.txt'  
data_3 = read_data_from_file(file_path_3)
file_path_4= '../performance_data/vgg_16/model_4/model_4.txt'  
data_4 = read_data_from_file(file_path_4)
data = [data_1,data_2,data_3,data_4]
labels= ["lr:1e-3/SGD","lr:1e-3/Adam","lr:2e-5/SGD","lr:2e-5/Adam"]
plot_all_metrics(data,labels,title="vgg_16")

# %% [markdown]
# #### Visual Transformer

# %%
file_path_1= '../performance_data/vis_performance.txt'  
data_1 = read_data_from_file(file_path_1)
file_path_2= '../performance_data/vis_performance1.txt'  
data_2 = read_data_from_file(file_path_2)
data = [data_1,data_2]
labels= ["model 1","model 2"]
plot_all_metrics(data,labels,title="Visual transformer")

# %% [markdown]
# ### Resenet

# %%
file_path_1= '../performance_data/resnet_performance.txt'  
data_1 = read_data_from_file(file_path_1)
data = [data_1]
labels= ["model 1"]
plot_all_metrics(data,labels,title="Visual transformer")

# %% [markdown]
# ### Unet

# %%
file_path_1= '../performance_data/unet/adam_1e-2.txt'
data_1 = read_data_from_file(file_path_1)
file_path_2= '../performance_data/unet/adam_1e-3.txt'
data_2 = read_data_from_file(file_path_2)
file_path_3= '../performance_data/unet/adam_2e-5.txt'
data_3 = read_data_from_file(file_path_3)
file_path_4= '../performance_data/unet/sgd_1e-2.txt' 
data_4 = read_data_from_file(file_path_4)
file_path_5= '../performance_data/unet/sgd_1e-2.txt'
data_5 = read_data_from_file(file_path_5)
file_path_6= '../performance_data/unet/sgd_2e-5.txt'
data_6 = read_data_from_file(file_path_6)

data = [data_1,data_2,data_3,data_4,data_5,data_6]
labels= ["[lr:1e-2/adam]","[lr:1e-3/adam]","[lr:2e-5/adam]","[lr:1e-2/SGD]","[lr:1e-3/SGD]","[lr:2e-5/SGD]"]
plot_all_metrics(data,labels,title="vgg_16")

# %% [markdown]
# ### Multi Plot

# %%
file_path_1= '../performance_data/vgg_16/model_1/model_1.txt'  
data_1 = read_data_from_file(file_path_1)
file_path_2= '../performance_data/vgg_16/model_2/model_2.txt'  
data_2 = read_data_from_file(file_path_2)
file_path_3= '../performance_data/vgg_16/model_3/model_3.txt'  
data_3 = read_data_from_file(file_path_3)
file_path_4= '../performance_data/vgg_16/model_4/model_4.txt'  
data_4 = read_data_from_file(file_path_4)


file_path_5= '../performance_data/vis_performance.txt'  
data_5 = read_data_from_file(file_path_5)
file_path_6= '../performance_data/vis_performance1.txt'  
data_6 = read_data_from_file(file_path_6)

file_path_7= '../performance_data/resnet_performance.txt'  
data_7 = read_data_from_file(file_path_7)



data = [data_1,data_2,data_3,data_4,data_5,data_6,data_7]
labels= ["VGG:[lr:1e-3/SGD]","VGG:[lr:1e-3/Adam]","VGG:[lr:2e-5/SGD]","VGG:[lr:2e-5/Adam]","VT 1","VT2","Resnet"]
plot_all_metrics(data,labels,title="vgg_16")

# %% [markdown]
# ### Best Runs

# %%
file_path_1= '../performance_data/vgg_16/model_4/model_4.txt'  
data_1 = read_data_from_file(file_path_1)
file_path_2= '../performance_data/unet/adam_1e-3.txt'
data_2 = read_data_from_file(file_path_2)
file_path_3= '../performance_data/vis_performance1.txt'  
data_3 = read_data_from_file(file_path_3)




data = [data_1,data_2,data_3]
labels= ["VGG:[lr:2e-5/Adam]","unet","VT"]
plot_all_metrics(data,labels,title="vgg_16")
